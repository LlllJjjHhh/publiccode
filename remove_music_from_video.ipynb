# %% [markdown]
# <a href="https://colab.research.google.com/github/LlllJjjHhh/publiccode/blob/master/remove_music_from_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  The code is written by S. A. Saleque Ahmed

# %%
# !pip install spleeter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install moviepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !spleeter separate --help
# Out:
# Usage: spleeter separate [OPTIONS] FILES...
#
#   Separate audio file(s)
#
# Arguments:
#   FILES...  List of input audio file path
#             [required]
#
#
# Options:
#   -i, --inputs TEXT               (DEPRECATED)
#                                   placeholder for
#                                   deprecated input
#                                   option
#
#   -a, --adapter TEXT              Name of the
#                                   audio adapter to
#                                   use for audio
#                                   I/O  [default: s
#                                   pleeter.audio.ff
#                                   mpeg.FFMPEGProce
#                                   ssAudioAdapter]
#
#   -b, --bitrate TEXT              Audio bitrate to
#                                   be used for the
#                                   separated output
#                                   [default: 128k]
#
#   -c, --codec [wav|mp3|ogg|m4a|wma|flac]
# ...

# %%
# video_name="/content/sample_data/16.wav"
# from moviepy.editor import *
# !spleeter separate -o . -c mp3 "/content/sample_data/16.wav"
# clip:VideoFileClip = VideoFileClip(video_name)
# clip = clip.without_audio()
# audioclip = AudioFileClip(f"{video_name[0:-4]}/vocals.mp3")
# clip=clip.set_audio(audioclip)
# clip.write_videofile(f"{video_name[0:-4]}_without_music.mp4")
# Out:
# INFO:spleeter:File ./16/accompaniment.mp3 written succesfully
# INFO:spleeter:File ./16/vocals.mp3 written succesfully

# %%
# !rm video3/vocals.mp3
# !rm video3/accompaniment.mp3

# can not music from video greater than 10 minutes
# Out:
# rm: cannot remove 'video3/vocals.mp3': No such file or directory
# rm: cannot remove 'video3/accompaniment.mp3': No such file or directory

# %%
import IPython.display as ipd

# %%
ipd.Audio("/content/16/accompaniment.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio("/content/16/vocals.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
